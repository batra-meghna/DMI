# %% [markdown]
# #Deep Support Vector Data Description for Unsupervised and Semi-Supervised Anomaly Detection

# %% [markdown]
# ---
#
#
# Connecting  to the  Google drive for easy import and export of data
#
#
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install barbar
# Out:
# Requirement already satisfied: barbar in /usr/local/lib/python3.7/dist-packages (0.2.1)

# %%
# Import all dependencies
import torch
import numpy as np
from torch.utils import data
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torch.utils.data import Subset
from PIL import Image
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
import torch.nn.functional as F
import numpy as np
from barbar import Bar
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Starting with the algorithm :
#
#
# ---
#
#
# ### Deep Support Vector Data Description for Unsupervised and Semi-Supervised Anomaly Detection
#
#
# ---
#
# **Normalization**

# %%
def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find("Conv") != -1 and classname != 'Conv':
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find("Linear") != -1:
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)


def global_contrast_normalization(x):
    """Apply global contrast normalization to tensor. """
    # Mean over all features (pixels) per sample
    mean = torch.mean(x)  
    x -= mean
    x_scale = torch.mean(torch.abs(x))
    x /= x_scale
    return x

# %% [markdown]
# ---
# Create a Semi Supervised Data setting
#
# ---

# %%
def create_semisupervised_setting(labels, normal_classes, outlier_classes, known_outlier_classes,ratio_known_normal, ratio_known_outlier, ratio_pollution):
    """
    :param labels: np.array with labels of all dataset samples
    :param normal_classes: tuple with normal class labels
    :param outlier_classes: tuple with anomaly class labels
    :param known_outlier_classes: tuple with known (labeled) anomaly class labels
    :param ratio_known_normal: the desired ratio of known (labeled) normal samples
    :param ratio_known_outlier: the desired ratio of known (labeled) anomalous samples
    :param ratio_pollution: the desired pollution ratio of the unlabeled data with unknown (unlabeled) anomalies.
    :return: tuple with list of sample indices, list of original labels, and list of semi-supervised labels
    """
    idx_normal = np.argwhere(np.isin(labels, normal_classes)).flatten()
    idx_outlier = np.argwhere(np.isin(labels, outlier_classes)).flatten()
    idx_known_outlier_candidates = np.argwhere(np.isin(labels, known_outlier_classes)).flatten()

    n_normal = len(idx_normal)

    #Solve system of linear equations to obtain respective number of samples
    a = np.array([[1, 1, 0, 0],
                  [(1-ratio_known_normal), -ratio_known_normal, -ratio_known_normal, -ratio_known_normal],
                  [-ratio_known_outlier, -ratio_known_outlier, -ratio_known_outlier, (1-ratio_known_outlier)],
                  [0, -ratio_pollution, (1-ratio_pollution), 0]])
    b = np.array([n_normal, 0, 0, 0])
    x = np.linalg.solve(a, b)

    #Get number of samples
    n_known_normal = int(x[0])
    n_unlabeled_normal = int(x[1])
    n_unlabeled_outlier = int(x[2])
    n_known_outlier = int(x[3])

    perm_normal = np.random.permutation(n_normal)
    perm_outlier = np.random.permutation(len(idx_outlier))
    perm_known_outlier = np.random.permutation(len(idx_known_outlier_candidates))

    idx_known_normal = idx_normal[perm_normal[:n_known_normal]].tolist()
    idx_unlabeled_normal = idx_normal[perm_normal[n_known_normal:n_known_normal+n_unlabeled_normal]].tolist()
    idx_unlabeled_outlier = idx_outlier[perm_outlier[:n_unlabeled_outlier]].tolist()
    idx_known_outlier = idx_known_outlier_candidates[perm_known_outlier[:n_known_outlier]].tolist()

    # Get original class labels
    labels_known_normal = labels[idx_known_normal].tolist()
    labels_unlabeled_normal = labels[idx_unlabeled_normal].tolist()
    labels_unlabeled_outlier = labels[idx_unlabeled_outlier].tolist()
    labels_known_outlier = labels[idx_known_outlier].tolist()

    #Get semi-supervised setting labels
    semi_labels_known_normal = np.ones(n_known_normal).astype(np.int32).tolist()
    semi_labels_unlabeled_normal = np.zeros(n_unlabeled_normal).astype(np.int32).tolist()
    semi_labels_unlabeled_outlier = np.zeros(n_unlabeled_outlier).astype(np.int32).tolist()
    semi_labels_known_outlier = (-np.ones(n_known_outlier).astype(np.int32)).tolist()

    # Create final lists
    list_idx = idx_known_normal + idx_unlabeled_normal + idx_unlabeled_outlier + idx_known_outlier
    list_labels = labels_known_normal + labels_unlabeled_normal + labels_unlabeled_outlier + labels_known_outlier
    list_semi_labels = (semi_labels_known_normal + semi_labels_unlabeled_normal + semi_labels_unlabeled_outlier
                        + semi_labels_known_outlier)

    return list_idx, list_labels, list_semi_labels

# %% [markdown]
# ---
#
# Creating Torchvision MNIST class with additional targets for the semi-supervised setting.
#
# ---

# %%
from torchvision.datasets import MNIST
class MyMNIST(MNIST):
    def __init__(self, *args, **kwargs):
        super(MyMNIST, self).__init__(*args, **kwargs)

        self.semi_targets = torch.zeros_like(self.targets)

    def __getitem__(self, index):
        img, target, semi_target = self.data[index], int(self.targets[index]), int(self.semi_targets[index])
        img = Image.fromarray(img.numpy(), mode='L')

        if self.transform is not None:
            img = self.transform(img)

        if self.target_transform is not None:
            target = self.target_transform(target)

        return img, target, semi_target, index

# %% [markdown]
# ---
#
# Loading the datset from drive.
#
#
# ---

# %%
def get_mnist(args, data_dir='/content/drive/MyDrive/Data'):
    n_classes = 2  # 0: normal, 1: outlier
    normal_classes = tuple([args.normal_class])
    outlier_classes = list(range(0, 10))
    outlier_classes.remove(args.normal_class)
    outlier_classes = tuple(outlier_classes)

    if args.n_known_outlier_classes == 0:
        known_outlier_classes = ()
    elif args.n_known_outlier_classes == 1:
        known_outlier_classes = tuple([args.known_outlier_class])
    else:
        known_outlier_classes = tuple(random.sample(outlier_classes, args.n_known_outlier_classes))
    
    transform = transforms.ToTensor()
    target_transform = transforms.Lambda(lambda x: int(x in outlier_classes))
    
    train = MyMNIST(root=data_dir, train=True,transform=transform, target_transform=target_transform,download=True)
    idx, _, semi_targets = create_semisupervised_setting(train.targets.cpu().data.numpy(), normal_classes,
                                                             outlier_classes, known_outlier_classes,
                                                             args.ratio_known_normal, args.ratio_known_outlier, args.ratio_pollution)
    train.semi_targets[idx] = torch.tensor(semi_targets)
    train = Subset(train, idx)          
    dataloader_train = DataLoader(train, batch_size=args.batch_size, 
                                  shuffle=True, num_workers=0)
    
    test = MyMNIST(root=data_dir, train=False, transform=transform, target_transform=target_transform,
                                download=True)
    dataloader_test = DataLoader(test, batch_size=args.batch_size, 
                                  shuffle=True, num_workers=0)
    return dataloader_train, dataloader_test

# %%
class network(nn.Module):
    def __init__(self, z_dim=32):
        super(network, self).__init__()
        self.pool = nn.MaxPool2d(2, 2)

        self.conv1 = nn.Conv2d(1, 8, 5, bias=False, padding=2)
        self.bn1 = nn.BatchNorm2d(8, eps=1e-04, affine=False)
        self.conv2 = nn.Conv2d(8, 4, 5, bias=False, padding=2)
        self.bn2 = nn.BatchNorm2d(4, eps=1e-04, affine=False)
        self.fc1 = nn.Linear(4 * 7 * 7, z_dim, bias=False)

    def forward(self, x):
        x = self.conv1(x)
        x = self.pool(F.leaky_relu(self.bn1(x)))
        x = self.conv2(x)
        x = self.pool(F.leaky_relu(self.bn2(x)))
        x = x.view(x.size(0), -1)
        return self.fc1(x)

# %% [markdown]
# ---
#
# Autoencoder class for MNIST Dataset
#
# ---

# %%
class autoencoder(nn.Module):
    def __init__(self, z_dim=32):
        super(autoencoder, self).__init__()
        self.z_dim = z_dim
        self.pool = nn.MaxPool2d(2, 2)

        self.conv1 = nn.Conv2d(1, 8, 5, bias=False, padding=2)
        self.bn1 = nn.BatchNorm2d(8, eps=1e-04, affine=False)
        self.conv2 = nn.Conv2d(8, 4, 5, bias=False, padding=2)
        self.bn2 = nn.BatchNorm2d(4, eps=1e-04, affine=False)
        self.fc1 = nn.Linear(4 * 7 * 7, z_dim, bias=False)

        self.deconv1 = nn.ConvTranspose2d(2, 4, 5, bias=False, padding=2)
        self.bn3 = nn.BatchNorm2d(4, eps=1e-04, affine=False)
        self.deconv2 = nn.ConvTranspose2d(4, 8, 5, bias=False, padding=3)
        self.bn4 = nn.BatchNorm2d(8, eps=1e-04, affine=False)
        self.deconv3 = nn.ConvTranspose2d(8, 1, 5, bias=False, padding=2)
        
    def encode(self, x):
        x = self.conv1(x)
        x = self.pool(F.leaky_relu(self.bn1(x)))
        x = self.conv2(x)
        x = self.pool(F.leaky_relu(self.bn2(x)))
        x = x.view(x.size(0), -1)
        return self.fc1(x)
   
    def decode(self, x):
        x = x.view(x.size(0), int(self.z_dim / 16), 4, 4)
        x = F.interpolate(F.leaky_relu(x), scale_factor=2)
        x = self.deconv1(x)
        x = F.interpolate(F.leaky_relu(self.bn3(x)), scale_factor=2)
        x = self.deconv2(x)
        x = F.interpolate(F.leaky_relu(self.bn4(x)), scale_factor=2)
        x = self.deconv3(x)
        return torch.sigmoid(x)
        

    def forward(self, x):
        z = self.encode(x)
        x_hat = self.decode(z)
        return x_hat

# %% [markdown]
# ## TRAINING
#
# ---
#
# Trainer Class for dataset
#
# ---

# %%
class TrainerDeepSAD:
    def __init__(self, args, data, device):
        self.args = args
        self.train_loader, self.test_loader = data
        self.device = device
    

    def pretrain(self):
        """ Pretraining the weights for the deep SAD network using autoencoder"""
        ae = autoencoder(self.args.latent_dim).to(self.device)
        ae.apply(weights_init_normal)
        optimizer = optim.Adam(ae.parameters(), lr=self.args.lr_ae,
                               weight_decay=self.args.weight_decay_ae)
        scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
                    milestones=self.args.lr_milestones, gamma=0.1)
        
        ae.train()
        for epoch in range(self.args.num_epochs_ae):
            total_loss = 0
            for x, _, _, _ in Bar(self.train_loader):
                x = x.float().to(self.device)
                
                optimizer.zero_grad()
                x_hat = ae(x)
                reconst_loss = torch.mean(torch.sum((x_hat - x) ** 2, dim=tuple(range(1, x_hat.dim()))))
                reconst_loss.backward()
                optimizer.step()
                
                total_loss += reconst_loss.item()
            scheduler.step()
            print('Pretraining Autoencoder... Epoch: {}, Loss: {:.3f}'.format(
                   epoch, total_loss/len(self.train_loader)))
        self.save_weights_for_DeepSAD(ae, self.train_loader) 
    
    # pretrained_parameters.pth file contains the parameters which are formed after pre-training of the data.
    def save_weights_for_DeepSAD(self, model, dataloader):
        """Initialize Deep SAD weights using the encoder weights of the pretrained autoencoder."""
        c = self.set_c(model, dataloader)
        net = network(self.args.latent_dim).to(self.device)
        state_dict = model.state_dict()
        net.load_state_dict(state_dict, strict=False)
        torch.save({'center': c.cpu().data.numpy().tolist(),
                    'net_dict': net.state_dict()}, '/content/drive/MyDrive/weights/pretrained_parameters.pth')
    

    def set_c(self, model, dataloader, eps=0.1):
        """Initializing the center for the hypersphere"""
        model.eval()
        z_ = []
        with torch.no_grad():
            for x, _, _, _ in dataloader:
                x = x.float().to(self.device)
                z = model.encode(x)
                z_.append(z.detach())
        z_ = torch.cat(z_)
        c = torch.mean(z_, dim=0)
        c[(abs(c) < eps) & (c < 0)] = -eps
        c[(abs(c) < eps) & (c > 0)] = eps
        return c


    def train(self):
        """Training the Deep SAD model"""
        net = network().to(self.device)
        eta=1
        eps=1e-6
        if self.args.pretrain==True:
            state_dict = torch.load('/content/drive/MyDrive/weights/pretrained_parameters.pth')
            net.load_state_dict(state_dict['net_dict'])
            c = torch.Tensor(state_dict['center']).to(self.device)
        else:
            net.apply(weights_init_normal)
            c = torch.randn(self.args.latent_dim).to(self.device)
        
        optimizer = optim.Adam(net.parameters(), lr=self.args.lr,
                               weight_decay=self.args.weight_decay)
        scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
                    milestones=self.args.lr_milestones, gamma=0.1)

        net.train()
        for epoch in range(self.args.num_epochs):
            total_loss = 0
            for x, _, sy, _ in Bar(self.train_loader):
                x = x.float().to(self.device)
                sy=sy.float().to(self.device)
                optimizer.zero_grad()
                z = net(x)
                dist = torch.sum((z-c) ** 2, dim=1)
                losses = torch.where(sy == 0, dist, eta * ((dist + eps) ** sy.float()))
                loss = torch.mean(losses)
                loss.backward()
                optimizer.step()

                total_loss += loss.item()
            scheduler.step()
            print('Training Deep SAD........ ')
            print('Epoch: {}, Loss: {:.3f}'.format(
                   epoch, total_loss/len(self.train_loader)))
        self.net = net
        self.c = c

# %% [markdown]
# ##Testing Phase
#
#
# ---
#
# Evaluation Parameters: ROC AUC Score and Mean LOSS
#
# ---

# %%
def eval(net, c, dataloader, device):
    """Testing the Deep SAD model"""

    scores = []
    labels = []
    epoch_loss=0
    nb=0
    eta=1.0
    eps=1e-6
    net.eval()
    with torch.no_grad():
        for x, y, sy,_ in dataloader:
            x = x.float().to(device)
            y = y.float().to(device)
            sy= sy.float().to(device)
            z = net(x)
            dist = torch.sum((z-c) ** 2, dim=1)
            losses = torch.where(sy == 0, dist, eta * ((dist + eps) ** sy.float()))
            loss = torch.mean(losses)
            score=dist
            scores.append(score.detach().cpu())
            labels.append(y.cpu())
            epoch_loss+=loss
            nb+=1
    labels, scores = torch.cat(labels).numpy(), torch.cat(scores).numpy()
    print()
    print('ROC AUC score: {:.2f}'.format(roc_auc_score(labels, scores)*100))
    print('Mean loss: {:.2f}'.format(epoch_loss/nb))
    return labels, scores

# %%
class Args:
  def __init__(self, nclass):
    self.num_epochs=20
    self.num_epochs_ae=20
    self.patience=50
    self.lr=1e-4
    self.weight_decay=0.5e-6
    self.weight_decay_ae=0.5e-3
    self.lr_ae=1e-4
    self.lr_milestones=[50]
    self.batch_size=200
    self.pretrain=True
    self.latent_dim=32
    self.normal_class=nclass
    self.ratio_known_outlier=0.01
    self.ratio_known_normal=0.0
    self.ratio_pollution=0.1
    self.known_outlier_class=(nclass+1)%10
    self.n_known_outlier_classes=1

# %% [markdown]
# ---
# TESTING For 9 Classes
#
# ---

# %%
nscores=[]
inscores=[]
outscores=[] 
for i in range(10):
  args = Args(i)
  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
  data = get_mnist(args)
  deep_SAD = TrainerDeepSAD(args, data, device)
  if args.pretrain:
      deep_SAD.pretrain()
  deep_SAD.train()
  print()
  print()
  print("Testing for class :  ",i,".....")
  labels, scores = eval(deep_SAD.net, deep_SAD.c, data[1], device)
  nscores.append(roc_auc_score(labels, scores)*100)
  inscores.append(scores[np.where(labels==0)[0]])
  outscores.append(scores[np.where(labels==1)[0]])
# Out:
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 153.927
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 120.401
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 97.384
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 82.253
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 72.382
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 65.633
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 60.629
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 56.727
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 53.678
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 51.050
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 48.765
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 46.695
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 44.666
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 42.776
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 40.906
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 39.115
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 37.395
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 35.790
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 34.211
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 32.780
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 0, Loss: 0.835
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 1, Loss: 0.313
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 2, Loss: 0.164
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 3, Loss: 0.117
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 4, Loss: 0.093
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 5, Loss: 0.082
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 6, Loss: 0.074
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 7, Loss: 0.067
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 8, Loss: 0.063
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 9, Loss: 0.059
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 10, Loss: 0.056
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 11, Loss: 0.054
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 12, Loss: 0.052
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 13, Loss: 0.051
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 14, Loss: 0.051
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 15, Loss: 0.048
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 16, Loss: 0.046
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 17, Loss: 0.045
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 18, Loss: 0.044
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 19, Loss: 0.045
#
#
# Testing for class :   0 .....
#
# ROC AUC score: 96.31
# Mean loss: 0.15
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 204.614
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 155.651
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch:
[===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 37.467
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 36.627
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 35.859
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 0, Loss: 0.455
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 1, Loss: 0.188
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 2, Loss: 0.134
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 3, Loss: 0.110
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 4, Loss: 0.095
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 5, Loss: 0.085
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 6, Loss: 0.077
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 7, Loss: 0.071
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 8, Loss: 0.067
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 9, Loss: 0.063
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 10, Loss: 0.061
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 11, Loss: 0.058
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 12, Loss: 0.055
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 13, Loss: 0.054
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 14, Loss: 0.052
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 15, Loss: 0.050
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 16, Loss: 0.048
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 17, Loss: 0.048
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 18, Loss: 0.046
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 19, Loss: 0.045
#
#
# Testing for class :   4 .....
#
# ROC AUC score: 93.19
# Mean loss: 0.12
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 145.796
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 114.141
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 92.351
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 78.922
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 69.714
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 63.075
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 58.126
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 54.225
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 51.153
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 48.698
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 46.642
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 44.915
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 43.434
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 42.164
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 41.007
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 39.988
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 39.185
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 38.424
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 37.748
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 37.200
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 0, Loss: 0.620
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 1, Loss: 0.260
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 2, Loss: 0.171
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 3, Loss: 0.139
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 4, Loss: 0.122
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 5, Loss: 0.112
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 6, Loss: 0.101
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 7, Loss: 0.094
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 8, Loss: 0.091
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 9, Loss: 0.085
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 10, Loss: 0.080
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 11, Loss: 0.077
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 12, Loss: 0.074
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 13, Loss: 0.075
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 14, Loss: 0.070
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 15, Loss: 0.068
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 16, Loss: 0.066
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 17, Loss: 0.065
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 18, Loss: 0.063
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD........
# Epoch: 19, Loss: 0.062
#
#
# Testing for class :   5 .....
#
# ROC AUC score: 78.77
# Mean loss: 0.09
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 173.411
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 135.698
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 110.073
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 92.035
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 79.669
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 70.934
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 64.468
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 59.584
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 55.644
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 52.501
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 49.774
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 47.184
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 45.027
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 42.911
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 40.952
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 39.206
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 37.681
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 36.183
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 34.887
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 33.687
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 0, Loss: 0.322
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 1, Loss: 0.165
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 2, Loss: 0.113
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 3, Loss: 0.089
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 4, Loss: 0.077
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 5, Loss: 0.068
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 6, Loss: 0.063
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 7, Loss: 0.058
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 8, Loss: 0.054
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 9, Loss: 0.051
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 10, Loss: 0.049
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 11, Loss: 0.048
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 12, Loss: 0.046
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 13, Loss: 0.044
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 14, Loss: 0.043
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 15, Loss: 0.041
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 16, Loss: 0.041
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 17, Loss: 0.041
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 18, Loss: 0.039
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 19, Loss: 0.040
#
#
# Testing for class :   6 .....
#
# ROC AUC score: 98.30
# Mean loss: 0.15
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 152.556
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 115.582
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch:
[===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 15, Loss: 0.059
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 16, Loss: 0.057
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 17, Loss: 0.056
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 18, Loss: 0.055
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 19, Loss: 0.054
#
#
# Testing for class :   8 .....
#
# ROC AUC score: 88.77
# Mean loss: 0.12
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 179.243
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 141.712
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 112.171
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 90.385
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 75.830
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 66.132
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 59.517
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 54.813
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 51.350
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 48.673
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 46.566
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 44.865
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 43.489
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 42.313
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 41.331
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 40.481
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 39.704
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 39.052
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 38.395
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 37.650
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 0, Loss: 0.304
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 1, Loss: 0.133
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 2, Loss: 0.094
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 3, Loss: 0.080
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 4, Loss: 0.072
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 5, Loss: 0.067
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 6, Loss: 0.062
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 7, Loss: 0.057
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 8, Loss: 0.055
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 9, Loss: 0.052
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 10, Loss: 0.050
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 11, Loss: 0.049
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 12, Loss: 0.047
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 13, Loss: 0.046
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 14, Loss: 0.046
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 15, Loss: 0.043
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 16, Loss: 0.042
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 17, Loss: 0.042
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 18, Loss: 0.041
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD........
# Epoch: 19, Loss: 0.040
#
#
# Testing for class :   9 .....
#
# ROC AUC score: 90.04
# Mean loss: 0.11

# %% [markdown]
# #RESULTS
#
# ---
#
# The ROC Scores for all the classes
#
# ---

# %%
for i in range(10):
  print("ROC scores for class ",i," is: ",nscores[i])
# Out:
# ROC scores for class  0  is:  96.31164306077196
# ROC scores for class  1  is:  98.77401353140972
# ROC scores for class  2  is:  88.33588547393316
# ROC scores for class  3  is:  92.80452427890175
# ROC scores for class  4  is:  93.1941841594024
# ROC scores for class  5  is:  78.77104048872425
# ROC scores for class  6  is:  98.29830311711665
# ROC scores for class  7  is:  94.0329056589372
# ROC scores for class  8  is:  88.77153771149828
# ROC scores for class  9  is:  90.04124706139902

# %%
for i in range(10):
  in_ = pd.DataFrame(inscores[i], columns=['Inlier'])
  out_ = pd.DataFrame(outscores[i], columns=['Outlier'])
  fig, ax = plt.subplots()
  in_.plot.kde(ax=ax, legend=True, title='Outliers vs Inliers for calss '+str(i))
  out_.plot.kde(ax=ax, legend=True)
  plt.xlim(-0.05, 0.08)
  ax.grid(axis='x')
  ax.grid(axis='y')
  plt.show()
